# %% [markdown]
# # General Information
# >
# >Author: Lucas Lobianco De Matheo
# >
# >Title: **DataPreprocessing - DataSUS - COVID-19 - Brazil 2020**
# >
# >This dataset was obtained from the SUS website - Brazilian Unified Health System. These are SUS records on COVI-19 in
# > Brazilian's territory hospitals.
# >
# >Extension: .csv
# >
# >Source: https://opendatasus.saude.gov.br/dataset/srag-2020
# > the file in the link above was dowloaded on 2023-03-20.
# > The data obtained is in .csv format and updates can be obtained from the website:
# > - https://covid.saude.gov.br/
# > - https://dados.gov.br/dataset/notificacao_covid
# >
# >Date: 2023-03-21
# >
# > **Main Skills of this project:**
# > - **Data Preparation**
# > - **Data Cleansing**
# > - **Data Wrangling**
# > - Data Visualization

# %% [markdown]
# # Objective:
# > Clean and structure the data for further analysis

# %% [markdown]
# # Importing main Libraries

# %%
#!pip install pandas # intalação do pandas e numpy
#!pip install matplotlib # intalação do matplotlib
#!pip install seaborn # intalação do seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os # biblioteca nativa

# %% [markdown]
# # Importing Data
# - The folowing csv file can be found on my github page: https://github.com/LucasDeMatheo/COVID_19_DATASUS

# %%
#os.listdir()
os.chdir("raw_data");

# %%
df = pd.read_csv(r'INFLUD20-13-03-2023.csv', encoding='UTF-8', sep=';')
df.shape
# Out:
# (1200817, 153)

# %%
pd.options.display.max_columns = None
df.head(10);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200817 entries, 0 to 1200816
# Columns: 153 entries, DT_NOTIFIC to RES_IGA
# dtypes: float64(87), int64(9), object(57)
# memory usage: 1.4+ GB

# %% [markdown]
# ## Reducing dataset Atributes
# > **objective**: import only the most relevant attributes for this study

# %%
df.columns.values
# Out:
# array(['DT_NOTIFIC', 'SEM_NOT', 'DT_SIN_PRI', 'SEM_PRI', 'SG_UF_NOT',
#        'ID_REGIONA', 'CO_REGIONA', 'ID_MUNICIP', 'CO_MUN_NOT',
#        'ID_UNIDADE', 'CO_UNI_NOT', 'CS_SEXO', 'DT_NASC', 'NU_IDADE_N',
#        'TP_IDADE', 'COD_IDADE', 'CS_GESTANT', 'CS_RACA', 'CS_ESCOL_N',
#        'ID_PAIS', 'CO_PAIS', 'SG_UF', 'ID_RG_RESI', 'CO_RG_RESI',
#        'ID_MN_RESI', 'CO_MUN_RES', 'CS_ZONA', 'SURTO_SG', 'NOSOCOMIAL',
#        'AVE_SUINO', 'FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP',
#        'SATURACAO', 'DIARREIA', 'VOMITO', 'OUTRO_SIN', 'OUTRO_DES',
#        'PUERPERA', 'FATOR_RISC', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN',
#        'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI',
#        'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OBES_IMC', 'OUT_MORBI',
#        'MORB_DESC', 'VACINA', 'DT_UT_DOSE', 'MAE_VAC', 'DT_VAC_MAE',
#        'M_AMAMENTA', 'DT_DOSEUNI', 'DT_1_DOSE', 'DT_2_DOSE', 'ANTIVIRAL',
#        'TP_ANTIVIR', 'OUT_ANTIV', 'DT_ANTIVIR', 'HOSPITAL', 'DT_INTERNA',
#        'SG_UF_INTE', 'ID_RG_INTE', 'CO_RG_INTE', 'ID_MN_INTE',
#        'CO_MU_INTE', 'UTI', 'DT_ENTUTI', 'DT_SAIDUTI', 'SUPORT_VEN',
#        'RAIOX_RES', 'RAIOX_OUT', 'DT_RAIOX', 'AMOSTRA', 'DT_COLETA',
#        'TP_AMOSTRA', 'OUT_AMOST', 'PCR_RESUL', 'DT_PCR', 'POS_PCRFLU',
#        'TP_FLU_PCR', 'PCR_FLUASU', 'FLUASU_OUT', 'PCR_FLUBLI',
#        'FLUBLI_OUT', 'POS_PCROUT', 'PCR_VSR', 'PCR_PARA1', 'PCR_PARA2',
#        'PCR_PARA3', 'PCR_PARA4', 'PCR_ADENO', 'PCR_METAP', 'PCR_BOCA',
#        'PCR_RINO', 'PCR_OUTRO', 'DS_PCR_OUT', 'CLASSI_FIN', 'CLASSI_OUT',
#        'CRITERIO', 'EVOLUCAO', 'DT_EVOLUCA', 'DT_ENCERRA', 'DT_DIGITA',
#        'HISTO_VGM', 'PAIS_VGM', 'CO_PS_VGM', 'LO_PS_VGM', 'DT_VGM',
#        'DT_RT_VGM', 'PCR_SARS2', 'PAC_COCBO', 'PAC_DSCBO', 'OUT_ANIM',
#        'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA', 'TOMO_RES',
#        'TOMO_OUT', 'DT_TOMO', 'TP_TES_AN', 'DT_RES_AN', 'RES_AN',
#        'POS_AN_FLU', 'TP_FLU_AN', 'POS_AN_OUT', 'AN_SARS2', 'AN_VSR',
#        'AN_PARA1', 'AN_PARA2', 'AN_PARA3', 'AN_ADENO', 'AN_OUTRO',
#        'DS_AN_OUT', 'TP_AM_SOR', 'SOR_OUT', 'DT_CO_SOR', 'TP_SOR',
#        'OUT_SOR', 'DT_RES', 'RES_IGG', 'RES_IGM', 'RES_IGA'], dtype=object)

# %%
selected_columns = ['DT_NOTIFIC', 'DT_SIN_PRI', 'SG_UF_NOT','ID_MUNICIP', 'ID_UNIDADE', 'CS_SEXO', 'DT_NASC', 'CS_GESTANT',
                    'CS_RACA', 'CS_ESCOL_N', 'AVE_SUINO', 'FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO',
                    'DIARREIA', 'VOMITO', 'OUTRO_SIN', 'PUERPERA', 'FATOR_RISC', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN', 
                    'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OUT_MORBI',
                    'VACINA', 'ANTIVIRAL', 'TP_ANTIVIR', 'HOSPITAL', 'DT_INTERNA', 'UTI', 'DT_ENTUTI', 'DT_SAIDUTI',
                    'SUPORT_VEN', 'RAIOX_RES', 'DT_RAIOX', 'AMOSTRA', 'DT_COLETA', 'TP_AMOSTRA', 'PCR_RESUL', 'DT_PCR',
                    'CRITERIO', 'EVOLUCAO', 'DT_EVOLUCA', 'DT_ENCERRA']

# %%
# forcing every attribute as str
type_sequence = []
for v in selected_columns:
    type_sequence.append('str')

# %%
# Criating a dictionary to be used as reference to the usecoluns method on pd.read_csv
columns_types = dict(zip(selected_columns, type_sequence))
columns_types;

# %% [markdown]
# # Reimporting the file with the selected columns

# %%
df = pd.read_csv(r'INFLUD20-13-03-2023.csv', encoding='UTF-8', sep=';', usecols=selected_columns, dtype=columns_types)
df.shape
# Out:
# (1200817, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200817 entries, 0 to 1200816
# Data columns (total 54 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   DT_NOTIFIC  1200817 non-null  object
#  1   DT_SIN_PRI  1200817 non-null  object
#  2   SG_UF_NOT   1200817 non-null  object
#  3   ID_MUNICIP  1200817 non-null  object
#  4   ID_UNIDADE  1200817 non-null  object
#  5   CS_SEXO     1200817 non-null  object
#  6   DT_NASC     1198684 non-null  object
#  7   CS_GESTANT  1200817 non-null  object
#  8   CS_RACA     1155391 non-null  object
#  9   CS_ESCOL_N  841380 non-null   object
#  10  AVE_SUINO   984925 non-null   object
#  11  FEBRE       1043560 non-null  object
#  12  TOSSE       1068221 non-null  object
#  13  GARGANTA    904213 non-null   object
#  14  DISPNEIA    1067351 non-null  object
#  15  DESC_RESP   1004352 non-null  object
#  16  SATURACAO   1010502 non-null  object
#  17  DIARREIA    891382 non-null   object
#  18  VOMITO      879985 non-null   object
#  19  OUTRO_SIN   890223 non-null   object
#  20  PUERPERA    484432 non-null   object
#  21  FATOR_RISC  1200817 non-null  object
#  22  CARDIOPATI  622625 non-null   object
#  23  HEMATOLOGI  488169 non-null   object
#  24  SIND_DOWN   486088 non-null   object
#  25  HEPATICA    487030 non-null   object
#  26  ASMA        497181 non-null   object
#  27  DIABETES    581782 non-null   object
#  28  NEUROLOGIC  501439 non-null   object
#  29  PNEUMOPATI  501973 non-null   object
#  30  IMUNODEPRE  493465 non-null   object
#  31  RENAL       497714 non-null   object
#  32  OBESIDADE   499139 non-null   object
#  33  OUT_MORBI   573342 non-null   object
#  34  VACINA      947102 non-null   object
#  35  ANTIVIRAL   1033418 non-null  object
#  36  TP_ANTIVIR  172329 non-null   object
#  37  HOSPITAL    1171813 non-null  object
#  38  DT_INTERNA  1111157 non-null  object
#  39  UTI         1034190 non-null  object
#  40  DT_ENTUTI   342002 non-null   object
#  41  DT_SAIDUTI  194863 non-null   object
#  42  SUPORT_VEN  1040305 non-null  object
#  43  RAIOX_RES   794214 non-null   object
#  44  DT_RAIOX    353135 non-null   object
#  45  AMOSTRA     1168485 non-null  object
#  46  DT_COLETA   1117624 non-null  object
#  47  TP_AMOSTRA  1099306 non-null  object
#  48  PCR_RESUL   1108354 non-null  object
#  49  DT_PCR      967612 non-null   object
#  50  CRITERIO    1141352 non-null  object
#  51  EVOLUCAO    1116020 non-null  object
#  52  DT_EVOLUCA  1042285 non-null  object
#  53  DT_ENCERRA  1121480 non-null  object
# dtypes: object(54)
# memory usage: 494.7+ MB

# %%
df.head(10)
# Out:
#    DT_NOTIFIC  DT_SIN_PRI SG_UF_NOT ID_MUNICIP  \
# 0  10/01/2020  07/01/2020        DF   BRASILIA
# 1  07/01/2020  03/01/2020        DF   BRASILIA
# 2  27/01/2020  26/01/2020        CE  FORTALEZA
# 3  16/01/2020  10/01/2020        SP    TAUBATE
# 4  13/02/2020  08/02/2020        SP      SALTO
# 5  18/02/2020  11/02/2020        TO     PALMAS
# 6  26/02/2020  24/02/2020        SP       MAUA
# 7  09/03/2020  05/03/2020        PR   CURITIBA
# 8  12/03/2020  25/02/2020        DF   BRASILIA
# 9  12/03/2020  10/03/2020        MG    UBERABA
#
#                                           ID_UNIDADE CS_SEXO     DT_NASC  \
# 0        HOSPITAL MATERNO INFANTIL DR ANTONIO LISBOA       M  26/06/2019
# 1                HRT HOSPITAL REGIONAL DE TAGUATINGA       M  08/06/2018
# 2                HIAS HOSPITAL INFANTIL ALBERT SABIN       M  05/04/2019
# 3               HOSPITAL REGIONAL DO VALE DO PARAIBA       M  14/11/2018
# 4  HOSPITAL E MATERNIDADE MUNICIPAL N S DO MONTE ...       F  01/05/1962
# 5  HOSPITAL E MATERNIDADE D REGINA S CAMPOS DE PA...       F  19/12/2019
# 6                                 SANTA CASA DE MAUA       F  07/07/1991
# 7              CENTRO MEDICO COMUNITARIO BAIRRO NOVO       F  18/05/1990
# 8                                               HRPL       F  20/08/1964
# 9  CLINICAS INTEGRADAS HOSPITAL UNIVERSITARIO MAR...       M  27/11/1987
#
#   CS_GESTANT CS_RACA CS_ESCOL_N AVE_SUINO FEBRE TOSSE GARGANTA DISPNEIA  \
# 0          6       4          5         2     1     1        2        1
# 1          6       4          5         2     1     1        2        9
# 2          6       4          5         2     1     1        2        1
# 3          6       1          5         2     1     1        1        2
# 4          5       1          9         2     1     1        2        1
# 5          6     NaN          5         2     1     1        9        1
# 6          5       1          4         9     1     1        2        2
# 7          3       1          3         2     1     1        1        1
# 8          5       4          2         2     1     1        1        1
# 9          6       1          4         2     1     1        1        1
#
#   DESC_RESP SATURACAO DIARREIA VOMITO OUTRO_SIN PUERPERA FATOR_RISC  \
# 0         1         1        2      2         2      NaN          S
# 1         1         1        2      2         1      NaN          N
# 2         1         1        1      1         1      NaN          N
# 3         1         2        2      1         2      NaN          N
# 4         1         1        2      2       NaN        2          S
# 5         1         2        2      2         9      NaN          S
# 6         2         2        2      2         2      NaN          N
# 7         2         2        2      2         2      NaN          N
# 8         1         1        1      1         2        2          S
# 9         2         2        2      2         1      NaN          N
#
#   CARDIOPATI HEMATOLOGI SIND_DOWN HEPATICA ASMA DIABETES NEUROLOGIC  \
# 0        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 1        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 2        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 3        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 4          1          2         2        2    2        1          2
# 5        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 6        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 7        NaN        NaN       NaN      NaN  NaN      NaN        NaN
# 8          2          2         2        2    2        2          2
# 9        NaN        NaN       NaN      NaN  NaN      NaN        NaN
#
#   PNEUMOPATI IMUNODEPRE RENAL OBESIDADE OUT_MORBI VACINA ANTIVIRAL TP_ANTIVIR  \
# 0          1          1   NaN       NaN         1      2         2        NaN
# 1        NaN        NaN   NaN       NaN       NaN      1         2        NaN
# 2        NaN        NaN   NaN       NaN       NaN    NaN         1          1
# 3        NaN        NaN   NaN       NaN       NaN      2         1          1
# 4          2          2     2         2       NaN      9         1          1
# 5        NaN        NaN   NaN       NaN         1    NaN         2        NaN
# 6        NaN        NaN   NaN       NaN       NaN      1         2        NaN
# 7        NaN        NaN   NaN       NaN       NaN      2         1          1
# 8          2          2     2         2         1      2         2        NaN
# 9        NaN        NaN   NaN       NaN       NaN      9         2        NaN
#
#   HOSPITAL  DT_INTERNA  UTI   DT_ENTUTI DT_SAIDUTI SUPORT_VEN RAIOX_RES  \
# 0        1  09/01/2020    2         NaN        NaN          2         6
# 1        1  06/01/2020    2         NaN        NaN          2         5
# 2        1  26/01/2020    2         NaN        NaN          1       NaN
# 3        1  16/01/2020    2         NaN        NaN          3         5
# 4        1  12/02/2020    1  12/02/2020        NaN          1         2
# 5        1  11/02/2020    2         NaN        NaN          3         5
# 6        2         NaN  NaN         NaN        NaN          3         6
# 7        1  09/03/2020    2         NaN        NaN          2         6
# 8        1  11/03/2020    2         NaN        NaN          2       NaN
# 9        2         NaN  NaN         NaN        NaN          3         6
#
#      DT_RAIOX AMOSTRA   DT_COLETA TP_AMOSTRA PCR_RESUL      DT_PCR CRITERIO  \
# 0         NaN       1  10/01/2020          1         1  17/01/2020        1
# 1  06/01/2020       2         NaN        NaN       NaN         NaN        3
# 2         NaN       1  27/01/2020          1         1  29/01/2020        1
# 3  16/01/2020       1  16/01/2020          1         1  07/02/2020      NaN
# 4  12/02/2020       1  13/02/2020          1         2  17/02/2020        1
# 5  12/02/2020       1  22/02/2020          1         2  24/02/2020        1
# 6         NaN       1  26/02/2020          1         2  02/03/2020        1
# 7         NaN       1  07/03/2020          1         1  10/03/2020        1
# 8         NaN       1  12/03/2020          1         2  16/03/2020        1
# 9         NaN       1  12/03/2020          1         1  19/03/2020        1
#
#   EVOLUCAO  DT_EVOLUCA  DT_ENCERRA
# 0        1  12/01/2020  17/01/2020
# 1        1  08/01/2020  09/01/2020
# 2        1         NaN  06/02/2020
# 3      NaN         NaN         NaN
# 4        2  13/02/2020  19/02/2020
# 5      NaN         NaN  26/02/2020
# 6        1         NaN  02/03/2020
# 7        1  10/03/2020  10/03/2020
# 8        1  13/03/2020  18/03/2020
# 9        1  27/04/2020  27/04/2020

# %%
(df.isnull().sum()/df.shape[0])
# Out:
# DT_NOTIFIC     0.000000
# DT_SIN_PRI     0.000000
# SG_UF_NOT      0.000000
# ID_MUNICIP     0.000000
# ID_UNIDADE     0.000000
# CS_SEXO        0.000000
# DT_NASC        0.177629
# CS_GESTANT     0.000000
# CS_RACA        3.782924
# CS_ESCOL_N    29.932704
# AVE_SUINO     17.978759
# FEBRE         13.095834
# TOSSE         11.042149
# GARGANTA      24.700183
# DISPNEIA      11.114599
# DESC_RESP     16.360944
# SATURACAO     15.848793
# DIARREIA      25.768706
# VOMITO        26.717810
# OUTRO_SIN     25.865223
# PUERPERA      59.658133
# FATOR_RISC     0.000000
# CARDIOPATI    48.149885
# HEMATOLOGI    59.346928
# SIND_DOWN     59.520227
# HEPATICA      59.441780
# ASMA          58.596439
# DIABETES      51.551152
# NEUROLOGIC    58.241847
# PNEUMOPATI    58.197377
# IMUNODEPRE    58.905895
# RENAL         58.552052
# OBESIDADE     58.433383
# OUT_MORBI     52.254007
# VACINA        21.128532
# ANTIVIRAL     13.940426
# TP_ANTIVIR    85.649021
# HOSPITAL       2.415356
# DT_INTERNA     7.466583
# UTI           13.876136
# DT_ENTUTI     71.519224
# DT_SAIDUTI    83.772465
# SUPORT_VEN    13.366899
# RAIOX_RES     33.860530
# DT_RAIOX      70.592105
# AMOSTRA        2.692500
# DT_COLETA      6.928033
# TP_AMOSTRA     8.453495
# PCR_RESUL      7.700008
# DT_PCR        19.420528
# CRITERIO       4.952045
# EVOLUCAO       7.061609
# DT_EVOLUCA    13.202012
# DT_ENCERRA     6.606918
# dtype: float64

# %% [markdown]
# # Applying attributes transformations

# %% [markdown]
# ## Gestante (pregnancy)

# %%
def pregnancy(v):
    if v == '1':
        return "1º quarter"
    elif v == '2':
        return "2º quarter"
    elif v == '3':
        return "3º quarter"
    elif v == '4':
        return "4º quarter"
    elif v == '5':
        return "Not pregnant"
    elif v == '6':
        return "Do not apply"
    else:
        return "Ignored"    
    
df['CS_GESTANT'] = list(map(pregnancy, df['CS_GESTANT']))

# %% [markdown]
# ## Raça (race)

# %%
def race(v):
    if v == '1':
        return "White"
    elif v == '2':
        return "Black"
    elif v == '3':
        return "Asian"
    elif v == '4':
        return "Mixed"
    elif v == '5':
        return "Indigenous"
    else:
        return "Ignored" 
df['CS_RACA'] = list(map(race, df['CS_RACA']))

# %% [markdown]
# ## Escolaridade (Schooling)

# %%
def schooling(v):
    if v == '0':
        return "Illiterate"
    elif v == '1':
        return "Elementary 1"
    elif v == '2':
        return "Elementary 2"
    elif v == '3':
        return "High school"
    elif v == '4':
        return "Higher education"
    elif v == '5':
        return "Do not aplly"
    else:
        return "Ignored" 
    
df['CS_ESCOL_N'] = list(map(schooling, df['CS_ESCOL_N']))

# %% [markdown]
# ## AVE_SUINO  (contact with poultry and swine)

# %%
def poultry_swine(v):
    if v == '1':
        return "Contact"
    elif v == '2':
        return "No Contact"
    else:
        return "Ignored" 
    
df['AVE_SUINO'] = list(map(poultry_swine, df['AVE_SUINO']))

# %% [markdown]
# ## Symptomatology

# %%
col = ['FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA', 'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO', 'OUTRO_SIN']

def symptomatology(v):
    if v == '1':
        return "1"
    elif v == '2':
        return "0"
    else:
        return "Ignored"

for symp in col:
    df[symp] = list(map(symptomatology, df[symp]))

# %% [markdown]
# ## Risk Factors

# %%
col = ['PUERPERA', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN', 'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC',
       'PNEUMOPATI', 'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OUT_MORBI']

def risk_factor(v):
    if v == '1':
        return "1"
    elif v == '2':
        return "0"
    else:
        return "Ignored"

for RF in col:
    df[RF] = list(map(risk_factor, df[RF]))

# %%
def risk_factor_general(v):
    if v == 'S':
        return "1"
    elif v == 'N':
        return "0"
    else:
        return "Ignored"

    
df['FATOR_RISC'] = list(map(risk_factor_general, df['FATOR_RISC']))

# %% [markdown]
# ## Pacient Historic

# %%
col = ['VACINA', 'ANTIVIRAL', 'TP_ANTIVIR', 'HOSPITAL', 'UTI']

def historic(v):
    if v == '1':
        return "1"
    elif v == '2':
        return "0"
    else:
        return "Ignored"

for hist in col:
    df[hist] = list(map(historic, df[hist]))

# %% [markdown]
# ## SUPORT_VEN (Ventilatory support)

# %%
def Ven_support(v):
    if v == '1':
        return "2"
    elif v == '2':
        return "1"
    elif v == '3':
        return '0'
    else:
        return "Ignored"

    
df['SUPORT_VEN'] = list(map(Ven_support, df['SUPORT_VEN']))

# 1 - Invasive
# 2 - non-Invasive
# 3 - Not needed

# %% [markdown]
# ## X-ray

# %%
def X_ray(v):
    if v == '1':
        return "Normal"
    elif v == '2':
        return "Interstitial infiltrate"
    elif v == '3':
        return 'Consolidation'
    elif v == '4':
        return 'Mixed'
    elif v == '5':
        return "Other"
    elif v == '6':
        return 'Not taken'
    else:
        return "Ignored"

    
df['RAIOX_RES'] = list(map(X_ray, df['RAIOX_RES']))

# %% [markdown]
# ## Sample

# %%
def Samples(v):
    if v == '1':
        return "1"
    elif v == '2':
        return "0"
    else:
        return "Ignored"

    
df['AMOSTRA'] = list(map(Samples, df['AMOSTRA']))

# %%
def SamplesType(v):
    if v == '1':
        return "Naso-oropharynx secretion"
    elif v == '2':
        return "Brocho-alveolar lavage"
    elif v == '3':
        return "Post-mortem tissue"
    elif v == '4':
        return "Other"
    elif v == '5':
        return "CSF - cerebrospinal fluid"
    else:
        return "Ignored"

    
df['TP_AMOSTRA'] = list(map(SamplesType, df['TP_AMOSTRA']))

# %% [markdown]
# ## PCR_RESUL (RT-PCR result)
# > This is an outcome/target variable

# %%
def RT_PCR(v):
    if v == '1':
        return "Detectable"
    elif v == '2':
        return "Not Detectable"
    elif v == '3':
        return "Inconclusive"
    elif v == '4':
        return "Not Done"
    elif v == '5':
        return "Awaiting Result"
    else:
        return "Ignored"

    
df['PCR_RESUL'] = list(map(RT_PCR, df['PCR_RESUL']))

# %% [markdown]
# ## Criterion

# %%
def RT_PCR(v):
    if v == '1':
        return "Laboratory"
    elif v == '2':
        return "Epidemiological"
    elif v == '3':
        return "Clinical"
    elif v == '4':
        return "Clinical Image"
    else:
        return "Ignored"

    
df['CRITERIO'] = list(map(RT_PCR, df['CRITERIO']))

# %% [markdown]
# ## EVOLUCAO (Evolution)
# > This is an second outcome/target variable

# %%
def Evolution(v):
    if v == '1':
        return "Cure"
    elif v == '2':
        return "Death"
    elif v == '3':
        return "Death from other causes"
    else:
        return "Ignored"

    
df['EVOLUCAO'] = list(map(Evolution, df['EVOLUCAO']))

# %% [markdown]
# # Dates

# %%
pd.to_datetime(df['DT_INTERNA'][1])
# Out:
# Timestamp('2020-06-01 00:00:00')

# %%
df['DT_INTERNA']
# Out:
# 0          09/01/2020
# 1          06/01/2020
# 2          26/01/2020
# 3          16/01/2020
# 4          12/02/2020
#               ...
# 1200812    25/12/2020
# 1200813           NaN
# 1200814           NaN
# 1200815    12/08/2020
# 1200816    15/04/2020
# Name: DT_INTERNA, Length: 1200817, dtype: object

# %%
'''for c, val in enumerate(df['DT_INTERNA']):
    if pd.notnull(val):
        year_str = str(val).split()[0][-4:-2]
        if year_str not in ['19','20']:
            print(val)
            correction_val = val.replace(year=2020)
            df.at[c, 'DT_INTERNA'] = correction_val
            print(f'Corrected to: {correction_val}')'''
# Out:
# "for c, val in enumerate(df['DT_INTERNA']):\n    if pd.notnull(val):\n        year_str = str(val).split()[0][-4:-2]\n        if year_str not in ['19','20']:\n            print(val)\n            correction_val = val.replace(year=2020)\n            df.at[c, 'DT_INTERNA'] = correction_val\n            print(f'Corrected to: {correction_val}')"

# %%
list_bool = df['DT_INTERNA'].isnull()

for c, val in enumerate(df['DT_INTERNA']):
    va = str(val).split()
    v = va[0][-4:-2]
    
    if list_bool[c] == False:        
        if v not in ['19','20']:
            print(val)
            
            correction_val = va[0][0:-4]
            correction_val = correction_val + '2020'
            
            df['DT_INTERNA'][c] = correction_val
            
            print(f'Corrected to: {correction_val}')
# Out:
# 24/12/5202
# Corrected to: 24/12/2020
# 19/05/2502
# Corrected to: 19/05/2020
# 29/06/6202
# Corrected to: 29/06/2020
# 22/06/9202
# Corrected to: 22/06/2020
# 16/04/7202
# Corrected to: 16/04/2020
# 07/12/2202
# Corrected to: 07/12/2020
# 27/12/2202
# Corrected to: 27/12/2020
# 29/06/2102
# Corrected to: 29/06/2020
# 06/05/2202
# Corrected to: 06/05/2020
# 11/10/5202
# Corrected to: 11/10/2020
# 03/06/2202
# Corrected to: 03/06/2020

# %%
df['DT_INTERNA'].describe()
# Out:
# count        1111157
# unique           723
# top       13/07/2020
# freq            5391
# Name: DT_INTERNA, dtype: object

# %%
list_bool = df['DT_ENTUTI'].isnull()

for c, val in enumerate(df['DT_ENTUTI']):
    va = str(val).split()
    v = va[0][-4:-2]
    
    if list_bool[c] == False:        
        if v not in ['19','20']:
            print(val)
            
            correction_val = va[0][0:-4]
            correction_val = correction_val + '2020'
            
            df['DT_ENTUTI'][c] = correction_val
            
            print(f'Corrected to: {correction_val}')
# Out:
# 05/08/4020
# Corrected to: 05/08/2020
# 28/12/2828
# Corrected to: 28/12/2020
# 24/12/2202
# Corrected to: 24/12/2020
# 19/11/2929
# Corrected to: 19/11/2020
# 02/08/2220
# Corrected to: 02/08/2020

# %%
df['DT_ENTUTI'].describe()
# Out:
# count         342002
# unique           583
# top       07/07/2020
# freq            1573
# Name: DT_ENTUTI, dtype: object

# %%
list_bool = df['DT_RAIOX'].isnull()

for c, val in enumerate(df['DT_RAIOX']):
    va = str(val).split()
    v = va[0][-4:-2]
    
    if list_bool[c] == False:        
        if v not in ['19','20']:
            print(val)
            
            correction_val = va[0][0:-4]
            correction_val = correction_val + '2020'
            
            df['DT_RAIOX'][c] = correction_val
            
            print(f'Corrected to: {correction_val}')
# Out:
# 20/02/2121
# Corrected to: 20/02/2020
# 15/09/2502
# Corrected to: 15/09/2020
# 18/05/8202
# Corrected to: 18/05/2020
# 19/11/2220
# Corrected to: 19/11/2020
# 29/07/3030
# Corrected to: 29/07/2020
# 18/11/2202
# Corrected to: 18/11/2020
# 01/09/6202
# Corrected to: 01/09/2020
# 12/07/5202
# Corrected to: 12/07/2020
# 18/06/8202
# Corrected to: 18/06/2020
# 31/08/2202
# Corrected to: 31/08/2020
# 13/07/4202
# Corrected to: 13/07/2020
# 30/03/4202
# Corrected to: 30/03/2020
# 27/05/6202
# Corrected to: 27/05/2020
# 31/07/8202
# Corrected to: 31/07/2020
# 10/07/2902
# Corrected to: 10/07/2020
# 24/10/2502
# Corrected to: 24/10/2020
# 25/02/5202
# Corrected to: 25/02/2020
# 28/12/2202
# Corrected to: 28/12/2020
# 13/07/4202
# Corrected to: 13/07/2020
# 04/04/2502
# Corrected to: 04/04/2020
# 23/09/2202
# Corrected to: 23/09/2020
# 26/04/5202
# Corrected to: 26/04/2020
# 16/02/7202
# Corrected to: 16/02/2020
# 19/06/2220
# Corrected to: 19/06/2020
# 06/12/2202
# Corrected to: 06/12/2020
# 06/05/8202
# Corrected to: 06/05/2020
# 02/05/8202
# Corrected to: 02/05/2020
# 04/08/9202
# Corrected to: 04/08/2020
# 14/04/2502
# Corrected to: 14/04/2020
# 07/12/2202
# Corrected to: 07/12/2020
# 12/05/3030
# Corrected to: 12/05/2020
# 14/06/9202
# Corrected to: 14/06/2020

# %%
list_bool = df['DT_COLETA'].isnull()

for c, val in enumerate(df['DT_COLETA']):
    va = str(val).split()
    v = va[0][-4:-2]
    
    if list_bool[c] == False:        
        if v not in ['19','20']:
            print(val)
            
            correction_val = va[0][0:-4]
            correction_val = correction_val + '2020'
            
            df['DT_COLETA'][c] = correction_val
            
            print(f'Corrected to: {correction_val}')
# Out:
# 18/05/8202
# Corrected to: 18/05/2020
# 03/01/2202
# Corrected to: 03/01/2020
# 14/08/5202
# Corrected to: 14/08/2020
# 12/12/2202
# Corrected to: 12/12/2020
# 20/01/5200
# Corrected to: 20/01/2020
# 29/07/2502
# Corrected to: 29/07/2020
# 07/06/2202
# Corrected to: 07/06/2020
# 09/08/9202
# Corrected to: 09/08/2020
# 30/08/2202
# Corrected to: 30/08/2020
# 16/06/9202
# Corrected to: 16/06/2020
# 13/07/2502
# Corrected to: 13/07/2020
# 30/03/2920
# Corrected to: 30/03/2020
# 03/07/2220
# Corrected to: 03/07/2020
# 31/05/6202
# Corrected to: 31/05/2020
# 29/12/2202
# Corrected to: 29/12/2020
# 01/01/2202
# Corrected to: 01/01/2020
# 16/12/2202
# Corrected to: 16/12/2020
# 25/07/2502
# Corrected to: 25/07/2020
# 21/05/2300
# Corrected to: 21/05/2020
# 10/10/5202
# Corrected to: 10/10/2020
# 21/05/5020
# Corrected to: 21/05/2020

# %%
df['DT_COLETA'].describe()
# Out:
# count        1117624
# unique           770
# top       13/07/2020
# freq            6172
# Name: DT_COLETA, dtype: object

# %%
for target in selected_columns:
    
    v = target.split()
    v = v[0][:2]
    
    if v == 'DT':
        print(target)
        df[target] = pd.to_datetime(df[target], format = '%d/%m/%Y')
        print('Ok')
    else:
        pass
# Out:
# DT_NOTIFIC
# Ok
# DT_SIN_PRI
# Ok
# DT_NASC
# Ok
# DT_INTERNA
# Ok
# DT_ENTUTI
# Ok
# DT_SAIDUTI
# Ok
# DT_RAIOX
# Ok
# DT_COLETA
# Ok
# DT_PCR
# Ok
# DT_EVOLUCA
# Ok
# DT_ENCERRA
# Ok

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200817 entries, 0 to 1200816
# Data columns (total 54 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   DT_NOTIFIC  1200817 non-null  datetime64[ns]
#  1   DT_SIN_PRI  1200817 non-null  datetime64[ns]
#  2   SG_UF_NOT   1200817 non-null  object
#  3   ID_MUNICIP  1200817 non-null  object
#  4   ID_UNIDADE  1200817 non-null  object
#  5   CS_SEXO     1200817 non-null  object
#  6   DT_NASC     1198684 non-null  datetime64[ns]
#  7   CS_GESTANT  1200817 non-null  object
#  8   CS_RACA     1200817 non-null  object
#  9   CS_ESCOL_N  1200817 non-null  object
#  10  AVE_SUINO   1200817 non-null  object
#  11  FEBRE       1200817 non-null  object
#  12  TOSSE       1200817 non-null  object
#  13  GARGANTA    1200817 non-null  object
#  14  DISPNEIA    1200817 non-null  object
#  15  DESC_RESP   1200817 non-null  object
#  16  SATURACAO   1200817 non-null  object
#  17  DIARREIA    1200817 non-null  object
#  18  VOMITO      1200817 non-null  object
#  19  OUTRO_SIN   1200817 non-null  object
#  20  PUERPERA    1200817 non-null  object
#  21  FATOR_RISC  1200817 non-null  object
#  22  CARDIOPATI  1200817 non-null  object
#  23  HEMATOLOGI  1200817 non-null  object
#  24  SIND_DOWN   1200817 non-null  object
#  25  HEPATICA    1200817 non-null  object
#  26  ASMA        1200817 non-null  object
#  27  DIABETES    1200817 non-null  object
#  28  NEUROLOGIC  1200817 non-null  object
#  29  PNEUMOPATI  1200817 non-null  object
#  30  IMUNODEPRE  1200817 non-null  object
#  31  RENAL       1200817 non-null  object
#  32  OBESIDADE   1200817 non-null  object
#  33  OUT_MORBI   1200817 non-null  object
#  34  VACINA      1200817 non-null  object
#  35  ANTIVIRAL   1200817 non-null  object
#  36  TP_ANTIVIR  1200817 non-null  object
#  37  HOSPITAL    1200817 non-null  object
#  38  DT_INTERNA  1111157 non-null  datetime64[ns]
#  39  UTI         1200817 non-null  object
#  40  DT_ENTUTI   342002 non-null   datetime64[ns]
#  41  DT_SAIDUTI  194863 non-null   datetime64[ns]
#  42  SUPORT_VEN  1200817 non-null  object
#  43  RAIOX_RES   1200817 non-null  object
#  44  DT_RAIOX    353135 non-null   datetime64[ns]
#  45  AMOSTRA     1200817 non-null  object
#  46  DT_COLETA   1117624 non-null  datetime64[ns]
#  47  TP_AMOSTRA  1200817 non-null  object
#  48  PCR_RESUL   1200817 non-null  object
#  49  DT_PCR      967612 non-null   datetime64[ns]
#  50  CRITERIO    1200817 non-null  object
#  51  EVOLUCAO    1200817 non-null  object
#  52  DT_EVOLUCA  1042285 non-null  datetime64[ns]
#  53  DT_ENCERRA  1121480 non-null  datetime64[ns]
# dtypes: datetime64[ns](11), object(43)
# memory usage: 494.7+ MB

# %%
df.head(5);

# %% [markdown]
# # Altering Columns Names

# %%
df_names = [ 'Notification_Date', 'First_Symptom_Date', 'State', 'County_ID', 'Health_Unit', 'Gender', 'Birth_Date', 'Pregnancy',
    'Race', 'Schooling', 'Poultry_Swine', 'Fever', 'Cough', 'Sore_Throat', 'Dyspnea', 'Respiratory_Discomfort', 
    'Saturation', 'Diarrhea', 'Vomiting', 'Other_Symptoms', 'Postpartum', 'Risk_Factors', 'Heart_Disease', 'Hematology',
    'Down_Syndrome', 'Liver_Disease', 'Asthma', 'Diabetes', 'Neuropathies', 'Lung_Disease', 'Immunosuppression',
    'Kidney_Disease', 'Obesity', 'Other_Morbidities', 'Vaccine', 'Antiviral', 'Antiviral_Type', 'Hospitalized', 'Admission_Date',
    'ICU', 'Intubation_Date', 'ICU_Discharge_Date', 'Ventilatory_Support', 'X_Ray_Result', 'X_Ray_Date', 'Sample', 'Sample_Date',
    'Sample_Type', 'PCR_Result', 'PCR_Date', 'Criterion', 'Evolution', 'Evolution_Date', 'Hospital_Discharge_Date']
df.columns = df_names

# %%
df
# Out:
#         Notification_Date First_Symptom_Date State        County_ID  \
# 0              2020-01-10         2020-01-07    DF         BRASILIA
# 1              2020-01-07         2020-01-03    DF         BRASILIA
# 2              2020-01-27         2020-01-26    CE        FORTALEZA
# 3              2020-01-16         2020-01-10    SP          TAUBATE
# 4              2020-02-13         2020-02-08    SP            SALTO
# ...                   ...                ...   ...              ...
# 1200812        2020-12-25         2020-12-23    MG     JUIZ DE FORA
# 1200813        2020-11-21         2020-11-17    PR    PRUDENTOPOLIS
# 1200814        2021-03-29         2020-07-06    RO  ESPIGAO D'OESTE
# 1200815        2021-12-01         2020-08-10    AL           MACEIO
# 1200816        2021-12-30         2020-04-15    PE           RECIFE
#
#                                                Health_Unit Gender Birth_Date  \
# 0              HOSPITAL MATERNO INFANTIL DR ANTONIO LISBOA      M 2019-06-26
# 1                      HRT HOSPITAL REGIONAL DE TAGUATINGA      M 2018-06-08
# 2                      HIAS HOSPITAL INFANTIL ALBERT SABIN      M 2019-04-05
# 3                     HOSPITAL REGIONAL DO VALE DO PARAIBA      M 2018-11-14
# 4        HOSPITAL E MATERNIDADE MUNICIPAL N S DO MONTE ...      F 1962-05-01
# ...                                                    ...    ...        ...
# 1200812                               HOSPITAL MONTE SINAI      M 1956-10-08
# 1200813                   HOSPITAL IRMANDADE DA SANTA CASA      M 1966-02-11
# 1200814              HOSPITAL MUNICIPAL ANGELINA GEORGETTI      M 1954-03-03
# 1200815            HOSPITAL DA MULHER DRA NISE DA SILVEIRA      M 1966-08-19
# 1200816                             HOSPITAL ILHA DO LEITE      M 1970-11-20
#
#             Pregnancy     Race     Schooling Poultry_Swine    Fever    Cough  \
# 0        Do not apply    Mixed  Do not aplly    No Contact        1        1
# 1        Do not apply    Mixed  Do not aplly    No Contact        1        1
# 2        Do not apply    Mixed  Do not aplly    No Contact        1        1
# 3        Do not apply    White  Do not aplly    No Contact        1        1
# 4        Not pregnant    White       Ignored    No Contact        1        1
# ...               ...      ...           ...           ...      ...      ...
# 1200812  Do not apply  Ignored       Ignored       Ignored  Ignored  Ignored
# 1200813  Do not apply    White       Ignored       Ignored  Ignored  Ignored
# 1200814  Do not apply    Mixed       Ignored    No Contact        1        1
# 1200815  Do not apply    Mixed       Ignored    No Contact        1        0
# 1200816  Do not apply  Ignored       Ignored       Ignored  Ignored  Ignored
#
#         Sore_Throat  Dyspnea Respiratory_Discomfort Saturation Diarrhea  \
# 0                 0        1                      1          1        0
# 1                 0  Ignored                      1          1        0
# 2                 0        1                      1          1        1
# 3                 1        0                      1          0        0
# 4                 0        1                      1          1        0
# ...             ...      ...                    ...        ...      ...
# 1200812     Ignored        1                Ignored    Ignored  Ignored
# 1200813     Ignored  Ignored                Ignored    Ignored  Ignored
# 1200814     Ignored        1                      1          1  Ignored
# 1200815           0        1                      0          0        1
# 1200816     Ignored        1                Ignored          1  Ignored
#
#         Vomiting Other_Symptoms Postpartum Risk_Factors Heart_Disease  \
# 0              0              0    Ignored            1       Ignored
# 1              0              1    Ignored            0       Ignored
# 2              1              1    Ignored            0       Ignored
# 3              1              0    Ignored            0       Ignored
# 4              0        Ignored          0            1             1
# ...          ...            ...        ...          ...           ...
# 1200812  Ignored        Ignored    Ignored            1             1
# 1200813  Ignored        Ignored    Ignored            0       Ignored
# 1200814  Ignored        Ignored    Ignored            0       Ignored
# 1200815        0              0          0            1             1
# 1200816  Ignored        Ignored    Ignored            0       Ignored
#
#         Hematology Down_Syndrome Liver_Disease   Asthma Diabetes Neuropathies  \
# 0          Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 1          Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 2          Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 3          Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 4                0             0             0        0        1            0
# ...            ...           ...           ...      ...      ...          ...
# 1200812    Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 1200813    Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 1200814    Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
# 1200815          0             0             0        0        1            0
# 1200816    Ignored       Ignored       Ignored  Ignored  Ignored      Ignored
#
#         Lung_Disease Immunosuppression Kidney_Disease  Obesity  \
# 0                  1                 1        Ignored  Ignored
# 1            Ignored           Ignored        Ignored  Ignored
# 2            Ignored           Ignored        Ignored  Ignored
# 3            Ignored           Ignored        Ignored  Ignored
# 4                  0                 0              0        0
# ...              ...               ...            ...      ...
# 1200812      Ignored           Ignored        Ignored  Ignored
# 1200813      Ignored           Ignored        Ignored  Ignored
# 1200814      Ignored           Ignored        Ignored  Ignored
# 1200815            0                 0              0        0
# 1200816      Ignored           Ignored        Ignored  Ignored
#
#         Other_Morbidities  Vaccine Antiviral Antiviral_Type Hospitalized  \
# 0                       1        0         0        Ignored            1
# 1                 Ignored        1         0        Ignored            1
# 2                 Ignored  Ignored         1              1            1
# 3                 Ignored        0         1              1            1
# 4                 Ignored  Ignored         1              1            1
# ...                   ...      ...       ...            ...          ...
# 1200812           Ignored  Ignored         0        Ignored            1
# 1200813           Ignored  Ignored   Ignored        Ignored      Ignored
# 1200814           Ignored  Ignored   Ignored        Ignored            1
# 1200815                 1  Ignored         0        Ignored            1
# 1200816           Ignored  Ignored   Ignored        Ignored            1
#
#         Admission_Date      ICU Intubation_Date ICU_Discharge_Date  \
# 0           2020-01-09        0             NaT                NaT
# 1           2020-01-06        0             NaT                NaT
# 2           2020-01-26        0             NaT                NaT
# 3           2020-01-16        0             NaT                NaT
# 4           2020-02-12        1      2020-02-12                NaT
# ...                ...      ...             ...                ...
# 1200812     2020-12-25        1      2020-12-25         2020-12-26
# 1200813            NaT  Ignored             NaT                NaT
# 1200814            NaT  Ignored             NaT                NaT
# 1200815     2020-08-12        0             NaT                NaT
# 1200816     2020-04-15        1      2020-04-15                NaT
#
#         Ventilatory_Support             X_Ray_Result X_Ray_Date   Sample  \
# 0                         1                Not taken        NaT        1
# 1                         1                    Other 2020-01-06        0
# 2                         2                  Ignored        NaT        1
# 3                         0                    Other 2020-01-16        1
# 4                         2  Interstitial infiltrate 2020-02-12        1
# ...                     ...                      ...        ...      ...
# 1200812                   1                  Ignored        NaT        1
# 1200813             Ignored                  Ignored        NaT        1
# 1200814             Ignored                  Ignored        NaT  Ignored
# 1200815                   1                  Ignored        NaT        1
# 1200816                   2                  Ignored        NaT  Ignored
#
#         Sample_Date                Sample_Type      PCR_Result   PCR_Date  \
# 0        2020-01-10  Naso-oropharynx secretion      Detectable 2020-01-17
# 1               NaT                    Ignored         Ignored        NaT
# 2        2020-01-27  Naso-oropharynx secretion      Detectable 2020-01-29
# 3        2020-01-16  Naso-oropharynx secretion      Detectable 2020-02-07
# 4        2020-02-13  Naso-oropharynx secretion  Not Detectable 2020-02-17
# ...             ...                        ...             ...        ...
# 1200812  2020-12-25  Naso-oropharynx secretion  Not Detectable 2020-12-30
# 1200813  2020-11-21                      Other      Detectable 2020-11-25
# 1200814         NaT                    Ignored         Ignored        NaT
# 1200815  2020-08-12  Naso-oropharynx secretion  Not Detectable 2020-08-13
# 1200816         NaT                    Ignored         Ignored        NaT
#
#           Criterion Evolution Evolution_Date Hospital_Discharge_Date
# 0        Laboratory      Cure     2020-01-12              2020-01-17
# 1          Clinical      Cure     2020-01-08              2020-01-09
# 2        Laboratory      Cure            NaT              2020-02-06
# 3           Ignored   Ignored            NaT                     NaT
# 4        Laboratory     Death     2020-02-13              2020-02-19
# ...             ...       ...            ...                     ...
# 1200812  Laboratory      Cure     2020-12-29              2021-07-13
# 1200813     Ignored     Death     2020-12-02                     NaT
# 1200814  Laboratory     Death     2020-07-17              2021-03-29
# 1200815  Laboratory      Cure     2020-08-16              2021-12-01
# 1200816     Ignored     Death     2020-04-16                     NaT
#
# [1200817 rows x 54 columns]

# %% [markdown]
# # Counting the "Ignored" data

# %%
df_ = df.replace('Ignored', np.nan)

# %%
(df_.isnull().sum()/df_.shape[0])
# Out:
# Notification_Date          0.000000
# First_Symptom_Date         0.000000
# State                      0.000000
# County_ID                  0.000000
# Health_Unit                0.000000
# Gender                     0.000000
# Birth_Date                 0.001772
# Pregnancy                  0.049999
# Race                       0.207377
# Schooling                  0.626907
# Poultry_Swine              0.336257
# Fever                      0.146006
# Cough                      0.123330
# Sore_Throat                0.273334
# Dyspnea                    0.122610
# Respiratory_Discomfort     0.178099
# Saturation                 0.177009
# Diarrhea                   0.282625
# Vomiting                   0.293058
# Other_Symptoms             0.287775
# Postpartum                 0.607317
# Risk_Factors               0.000000
# Heart_Disease              0.487941
# Hematology                 0.605570
# Down_Syndrome              0.606108
# Liver_Disease              0.606393
# Asthma                     0.597370
# Diabetes                   0.523390
# Neuropathies               0.593640
# Lung_Disease               0.593543
# Immunosuppression          0.600750
# Kidney_Disease             0.596739
# Obesity                    0.600566
# Other_Morbidities          0.530873
# Vaccine                    0.591506
# Antiviral                  0.275325
# Antiviral_Type             0.864265
# Hospitalized               0.027688
# Admission_Date             0.074657
# ICU                        0.160932
# Intubation_Date            0.715188
# ICU_Discharge_Date         0.837722
# Ventilatory_Support        0.174245
# X_Ray_Result               0.440337
# X_Ray_Date                 0.705917
# Sample                     0.032623
# Sample_Date                0.069277
# Sample_Type                0.086743
# PCR_Result                 0.079298
# PCR_Date                   0.194200
# Criterion                  0.049520
# Evolution                  0.091821
# Evolution_Date             0.132018
# Hospital_Discharge_Date    0.066069
# dtype: float64

# %% [markdown]
# # Looking for Duplicates

# %%
duplicates = df[df.duplicated() == True]
duplicates.shape
# Out:
# (22, 54)

# %%
df = df[df.duplicated() == False]

# %%
df.shape[1]
# Out:
# 54

# %%
df.to_csv(r'DataSUS_PreProcessed_2.csv', sep = ';', encoding='UTF-8', index=False)
